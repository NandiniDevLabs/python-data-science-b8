# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# 3410

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
len(df)
# Out:
# 244

# %%
def last_four(num):
    return str(num)[-4:]

# %%
type(3560325168603410)
# Out:
# int

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df['CC Number']
# Out:
# 0      3560325168603410
# 1      4478071379779230
# 2      6011812112971322
# 3      4676137647685994
# 4      4832732618637221
#              ...
# 239    5296068606052842
# 240    3506806155565404
# 241    6011891618747196
# 242       4375220550950
# 243    3511451626698139
# Name: CC Number, Length: 244, dtype: int64

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %% [markdown]
# ### Using .apply() with more complex functions

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four yelp
# 0    Christy Cunningham  3560325168603410    Sun2959      3410   $$
# 1        Douglas Tucker  4478071379779230    Sun4608      9230   $$
# 2        Travis Walters  6011812112971322    Sun4458      1322   $$
# 3      Nathaniel Harris  4676137647685994    Sun5260      5994   $$
# 4          Tonya Carter  4832732618637221    Sun2251      7221   $$
# ..                  ...               ...        ...       ...  ...
# 239       Michael Avila  5296068606052842    Sat2657      2842   $$
# 240      Monica Sanders  3506806155565404    Sat1766      5404   $$
# 241          Keith Wong  6011891618747196    Sat3880      7196   $$
# 242        Dennis Dixon     4375220550950      Sat17      0950   $$
# 243     Michelle Hardin  3511451626698139    Thur672      8139   $$
#
# [244 rows x 13 columns]

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def simple(num):
    return num*2

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four yelp
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   $$
# 2      Travis Walters  6011812112971322    Sun4458      1322   $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994   $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221   $$

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
# To understand what is happening internally
# df[['total_bill','tip']]
# df[['total_bill','tip']].head(10)
# df[['total_bill','tip']].head(4).apply(lambda df:print(df),axis=1)
df[['total_bill','tip']].head(4).apply(lambda df:print(df["total_bill"],df["tip"]),axis=1)
# Out:
# 16.99 1.01
# 10.34 1.66
# 21.01 3.5
# 23.68 3.31
# 0    None
# 1    None
# 2    None
# 3    None
# dtype: object

# %%
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four yelp Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$       Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   $$       Other
# 2      Travis Walters  6011812112971322    Sun4458      1322   $$       Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994   $$       Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221   $$       Other

# %%
import numpy as np

# %%
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four yelp Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$       Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   $$       Other
# 2      Travis Walters  6011812112971322    Sun4458      1322   $$       Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994   $$       Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221   $$       Other

# %% [markdown]
# So, which one is faster?

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 1.9011278999996648

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.2476345000004585

# %% [markdown]
# Wow! Vectorization is much faster! Keep **np.vectorize()** in mind for the future.
#
# Full Details:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values('tip')#head(7)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four yelp  \
# 92         Leah Ramirez  3508911676966392    Fri3780      6392    $
# 111         Terri Jones  3559221007826887    Sat4801      6887    $
# 67        Tiffany Brock  4359488526995267    Sat3455      5267    $
# 236       Matthew Myers  3543676378973965    Sat5032      3965   $$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410   $$
# ..                  ...               ...        ...       ...  ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508  $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595  $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808  $$$
# 212     Alex Williamson      676218815212    Sat4590      5212  $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236  $$$
#
#     Tip Quality
# 92        Other
# 111       Other
# 67     Generous
# 236       Other
# 0         Other
# ..          ...
# 141       Other
# 59        Other
# 23        Other
# 212       Other
# 170       Other
#
# [244 rows x 14 columns]

# %%
df.sort_values('tip',ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
#
#              Payer Name         CC Number Payment ID last_four yelp  \
# 170       Gregory Clark  5473850968388236    Sat1954      8236  $$$
# 212     Alex Williamson      676218815212    Sat4590      5212  $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808  $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595  $$$
# 141      Steven Carlson  3526515703718508   Thur1025      8508  $$$
# ..                  ...               ...        ...       ...  ...
# 0    Christy Cunningham  3560325168603410    Sun2959      3410   $$
# 111         Terri Jones  3559221007826887    Sat4801      6887    $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392    $
# 67        Tiffany Brock  4359488526995267    Sat3455      5267    $
# 236       Matthew Myers  3543676378973965    Sat5032      3965   $$
#
#     Tip Quality
# 170       Other
# 212       Other
# 23        Other
# 59        Other
# 141       Other
# ..          ...
# 0         Other
# 111       Other
# 92        Other
# 67     Generous
# 236       Other
#
# [244 rows x 14 columns]

# %%
# Helpful if you want to reorder after a sort
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four yelp  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267    $
# 111         Terri Jones  3559221007826887    Sat4801      6887    $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392    $
# 236       Matthew Myers  3543676378973965    Sat5032      3965   $$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410   $$
# ..                  ...               ...        ...       ...  ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508  $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595  $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808  $$$
# 212     Alex Williamson      676218815212    Sat4590      5212  $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236  $$$
#
#     Tip Quality
# 67     Generous
# 111       Other
# 92        Other
# 236       Other
# 0         Other
# ..          ...
# 141       Other
# 59        Other
# 23        Other
# 212       Other
# 170       Other
#
# [244 rows x 14 columns]

# %%
df.sort_values(['tip','size'],ascending=False) # descending order
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
#
#              Payer Name         CC Number Payment ID last_four yelp  \
# 170       Gregory Clark  5473850968388236    Sat1954      8236  $$$
# 212     Alex Williamson      676218815212    Sat4590      5212  $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808  $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595  $$$
# 141      Steven Carlson  3526515703718508   Thur1025      8508  $$$
# ..                  ...               ...        ...       ...  ...
# 0    Christy Cunningham  3560325168603410    Sun2959      3410   $$
# 92         Leah Ramirez  3508911676966392    Fri3780      6392    $
# 236       Matthew Myers  3543676378973965    Sat5032      3965   $$
# 67        Tiffany Brock  4359488526995267    Sat3455      5267    $
# 111         Terri Jones  3559221007826887    Sat4801      6887    $
#
#     Tip Quality
# 170       Other
# 212       Other
# 23        Other
# 59        Other
# 141       Other
# ..          ...
# 0         Other
# 92        Other
# 236       Other
# 67     Generous
# 111       Other
#
# [244 rows x 14 columns]

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
#  11  last_four         244 non-null    object
#  12  yelp              244 non-null    object
#  13  Tip Quality       244 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 26.8+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df = df.drop(['last_four','yelp','Tip Quality'],axis=1)

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
max_total_bill = df['total_bill'].max()
print(max_total_bill)
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].min()
# Out:
# np.float64(3.07)

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959       Other
# 1      Douglas Tucker  4478071379779230    Sun4608       Other
# 2      Travis Walters  6011812112971322    Sun4458       Other
# 3    Nathaniel Harris  4676137647685994    Sun5260       Other
# 4        Tonya Carter  4832732618637221    Sun2251       Other

# %%
df['Tip Quality'].value_counts()
# Out:
# Tip Quality
# Other       234
# Generous     10
# Name: count, dtype: int64

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')
# Out:
# 0      Ok
# 1      Ok
# 2      Ok
# 3      Ok
# 4      Ok
#        ..
# 239    Ok
# 240    Ok
# 241    Ok
# 242    Ok
# 243    Ok
# Name: Tip Quality, Length: 244, dtype: object

# %%
df['Tip Quality'] = df['Tip Quality'].replace(to_replace='Other',value='Ok')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959          Ok
# 1      Douglas Tucker  4478071379779230    Sun4608          Ok
# 2      Travis Walters  6011812112971322    Sun4458          Ok
# 3    Nathaniel Harris  4676137647685994    Sun5260          Ok
# 4        Tonya Carter  4832732618637221    Sun2251          Ok

# %%
df['Tip Quality'].value_counts()
# Out:
# Tip Quality
# Ok          234
# Generous     10
# Name: count, dtype: int64

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time'].map(my_map)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 239    D
# 240    D
# 241    D
# 242    D
# 243    D
# Name: time, Length: 244, dtype: object

# %%
df['map'] = df['time'].map(my_map)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality map
# 0  Christy Cunningham  3560325168603410    Sun2959          Ok   D
# 1      Douglas Tucker  4478071379779230    Sun4608          Ok   D
# 2      Travis Walters  6011812112971322    Sun4458          Ok   D
# 3    Nathaniel Harris  4676137647685994    Sun5260          Ok   D
# 4        Tonya Carter  4832732618637221    Sun2251          Ok   D

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.drop_duplicates(inplace=True)
# or 
# simple_df = simple_df.drop_duplicates()

# %%
simple_df
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary<br>
# right: A scalar value that defines the right boundary<br>
# inclusive: A String value: 'both','left', 'right', or 'neither'

# %%
df['total_bill'].between(15,20,inclusive='both')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(15,20,inclusive='neither')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 12        15.42  1.57    Male     No   Sun  Dinner     2              7.71
# 13        18.43  3.00    Male     No   Sun  Dinner     4              4.61
# 17        16.29  3.71    Male     No   Sun  Dinner     3              5.43
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Tip Quality map
# 0    Christy Cunningham  3560325168603410    Sun2959          Ok   D
# 8       Joseph Mcdonald  3522866365840377    Sun6820          Ok   D
# 12      Chad Harrington      577040572932    Sun1300          Ok   D
# 13         Joshua Jones  6011163105616890    Sun2971          Ok   D
# 17         John Pittman  6521340257218708    Sun2998          Ok   D
# ..                  ...               ...        ...         ...  ..
# 225      Whitney Arnold  3579111947217428    Fri6665          Ok   L
# 231         Jason Parks     4812333796161    Sat6334          Ok   D
# 234       Tracy Douglas  4097938155941930    Sat7220          Ok   D
# 242        Dennis Dixon     4375220550950      Sat17          Ok   D
# 243     Michelle Hardin  3511451626698139    Thur672          Ok   D
#
# [67 rows x 13 columns]

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.shape
# Out:
# (244, 13)

# %%
df.sample(5)
# Out:
#      total_bill   tip   sex smoker   day    time  size  price_per_person  \
# 80        19.44  3.00  Male    Yes  Thur   Lunch     2              9.72
# 53         9.94  1.56  Male     No   Sun  Dinner     2              4.97
# 26        13.37  2.00  Male     No   Sat  Dinner     2              6.68
# 220       12.16  2.20  Male    Yes   Fri   Lunch     2              6.08
# 24        19.82  3.18  Male     No   Sat  Dinner     2              9.91
#
#            Payer Name         CC Number Payment ID Tip Quality map
# 80       Louis Torres    38848369968464   Thur6453          Ok   L
# 53      Curtis Morgan  4628628020417301    Sun4561          Ok   D
# 26         Kyle Avery  6531339539615499    Sat6651          Ok   D
# 220     Ricky Johnson   213109508670736    Fri4607          Ok   L
# 24   Christopher Ross    36739148167928    Sat6236          Ok   D

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 64        17.59  2.64    Male     No   Sat  Dinner     3              5.86
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 88        24.71  5.85    Male     No  Thur   Lunch     2             12.36
# 70        12.02  1.97    Male     No   Sat  Dinner     2              6.01
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 124       12.48  2.52  Female     No  Thur   Lunch     2              6.24
# 74        14.73  2.20  Female     No   Sat  Dinner     2              7.36
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2             16.45
# 133       12.26  2.00  Female     No  Thur   Lunch     2              6.13
# 54        25.56  4.34    Male     No   Sun  Dinner     4              6.39
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 51        10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 57        26.41  1.50  Female     No   Sat  Dinner     2             13.20
# 35        24.06  3.60    Male     No   Sat  Dinner     3              8.02
# 163       13.81  2.00    Male     No   Sun  Dinner     2              6.90
# 49        18.04  3.00    Male     No   Sun  Dinner     2              9.02
# 65        20.08  3.15    Male     No   Sat  Dinner     3              6.69
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# 148        9.78  1.73    Male     No  Thur   Lunch     2              4.89
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4              9.68
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2              6.71
# 147       11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 134       18.26  3.25  Female     No  Thur   Lunch     2              9.13
#
#              Payer Name         CC Number Payment ID Tip Quality map
# 64      Michael Johnson  2222114458088108    Sat1667          Ok   D
# 237        Thomas Brown  4284722681265508    Sat2929          Ok   D
# 88         Roger Taylor     4410248629955   Thur9003          Ok   L
# 70            Max Brown   213139760497718    Sat2100          Ok   D
# 196         Eric Martin    30442491190342   Thur9862          Ok   L
# 124         Jordan Diaz  4472778228206399    Thur208          Ok   L
# 74        Ashley Harris      501828723483    Sat6548          Ok   D
# 175     Nathan Reynolds   370307040837149    Sun5109          Ok   D
# 133        Kaitlin Wolf      676348318145   Thur1561          Ok   L
# 54         Ronald Owens  6569607991983380    Sun9470          Ok   D
# 73         Julie Holmes  5418689346409571    Sat6065          Ok   D
# 145           Amy Young     4285454264477   Thur9331          Ok   L
# 51       Jessica Ibarra     4999759463713    Sun4474    Generous   D
# 57         Melody Simon  4745394421258160    Sat8980          Ok   D
# 35       Joseph Mullins  5519770449260299     Sat632          Ok   D
# 163      Charles Newton  5552793481414044    Sun8594          Ok   D
# 49         William Roth  6573923967142503    Sun9774          Ok   D
# 65         Justin Dixon   180021262464926    Sat6840          Ok   D
# 6    Kristopher Johnson  2223727524230344    Sun5985          Ok   D
# 148       David Stewart  3578014604116399   Thur7276          Ok   L
# 207       Ricky Ramirez   347817964484033    Sat4505          Ok   D
# 224   Ronald Vaughn DVM   341503466406403    Fri5959          Ok   L
# 147  Annette Cunningham      675937746864   Thur4780          Ok   L
# 134     Karen Rodriguez     4952604748911     Thur75          Ok   L

# %%
244*0.1
# Out:
# 24.400000000000002

# %%
df.sample(frac=0.1).shape
# Out:
# (24, 13)

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %%
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID Tip Quality map
# 170      Gregory Clark  5473850968388236    Sat1954          Ok   D
# 212    Alex Williamson      676218815212    Sat4590          Ok   D
# 23      Lance Peterson  3542584061609808     Sat239          Ok   D
# 59         Brian Ortiz  6596453823950595    Sat8139          Ok   D
# 141     Steven Carlson  3526515703718508   Thur1025          Ok   L
# 183  Dr. Michael James     4718501859162    Sun6059    Generous   D
# 214    Marissa Jackson  4922302538691962    Sat3374          Ok   D
# 47        James Barnes  3552002592874186    Sun9677          Ok   D
# 239      Michael Avila  5296068606052842    Sat2657          Ok   D
# 88        Roger Taylor     4410248629955   Thur9003          Ok   L

# %%
df.nlargest(3,'tip')
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No  Sat  Dinner     4              9.86
#
#           Payer Name         CC Number Payment ID Tip Quality map
# 170    Gregory Clark  5473850968388236    Sat1954          Ok   D
# 212  Alex Williamson      676218815212    Sat4590          Ok   D
# 23    Lance Peterson  3542584061609808     Sat239          Ok   D

# %%
df.nlargest(5,'price_per_person')
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 184       40.55   3.00  Male    Yes  Sun  Dinner     2             20.27
# 179       34.63   3.55  Male    Yes  Sun  Dinner     2             17.32
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 175       32.90   3.11  Male    Yes  Sun  Dinner     2             16.45
# 237       32.83   1.17  Male    Yes  Sat  Dinner     2             16.42
#
#           Payer Name         CC Number Payment ID Tip Quality map
# 184      Stephen Cox  3547798222044029    Sun5140          Ok   D
# 179     Brian Bailey   346656312114848    Sun9851          Ok   D
# 170    Gregory Clark  5473850968388236    Sat1954          Ok   D
# 175  Nathan Reynolds   370307040837149    Sun5109          Ok   D
# 237     Thomas Brown  4284722681265508    Sat2929          Ok   D

# %%
df.nlargest(10,'tip').shape
# Out:
# (10, 13)

# %% [markdown]
# ----
